# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn
from utils import tools
import numpy as np
import pandas as pd
from parsing import PostingHandler, aggregate
from analysis import transformation_pipeline, produce_results
from utils import constants
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/all_data.csv')

# %%
# dataframe = df[df.YEAR < 2018]

# %%
produce_results.job_dist_by_date_plot(dataframe)

# %%
produce_results.posting_dist_by_month_plot(dataframe)

# %%
produce_results.ministry_size_normalize_plot(dataframe)
# Out:
# removing nan ministerio values...

# %%
produce_results.ministry_by_size_plot(dataframe)
# Out:
# removing nan ministerio values...

# %%
produce_results.ministry_num_vac_normalize_plot(dataframe)
# Out:
# removing nan ministerio values...

# %%
produce_results.ministry_num_vac_budget_plot(dataframe)
# Out:
# removing nan ministerio values...

# %%
produce_results.wage_by_month_plot(dataframe)

# %%
produce_results.wage_by_month_all_plot(dataframe)

# %%
produce_results.wage_by_ministry_plot(dataframe)
# Out:
# removing nan ministerio values...

# %%
produce_results.vac_type_dist(dataframe)

# %%
produce_results.wage_by_vac_type_plot(dataframe)

# %%
produce_results.schedule_by_month_plot(dataframe)

# %%
produce_results.days_open_ministry_plot(dataframe)
# Out:
# removing nan ministerio values...

# %%
produce_results.days_open_by_month_all_plot(dataframe)

# %%
produce_results.days_open_contract_type_plot(dataframe)

# %%
produce_results.results_by_contract_type_plot(dataframe)

# %%
produce_results.results_by_ministry_plot(dataframe)
# Out:
# removing nan ministerio values...

# %%
produce_results.results_by_month_plot(dataframe)

# %%
produce_results.results_by_date_plot(dataframe)

# %%
mat = produce_results.heatmap_wage_ministry_vac_type_df(df)
title = 'Heatmap of Average Wage by Ministry and Vacancy Type'
# Out:
# removing nan ministerio values...

# %%
ax = plt.axes()
sns.heatmap(mat, ax=ax)
ax.set_title(title)
plt.show()

# %%
mat2 = produce_results.heatmap_days_open_ministry_vac_type_df(df)
# Out:
# removing nan ministerio values...

# %%
title = 'Heatmap of Average Days Open by Ministry and Vacancy Type'
ax = plt.axes()
sns.heatmap(mat2, ax=ax)
ax.set_title(title)
plt.show()

# %%
mat3 = produce_results.heatmap_wage_ministry_result_cat_df(df)
# Out:
# removing nan ministerio values...

# %%
title = 'Heatmap of Average Wage by Ministry and Result Category'
ax = plt.axes()
sns.heatmap(mat3, ax=ax)
ax.set_title(title)
plt.show()

# %%
produce_results.vacancies_by_region(df)

# %%
produce_results.wage_by_region(df)

# %%
produce_results.type_contract_by_date_plot(df)

# %%
produce_results.type_contract_by_month(df)
