# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn
from utils import tools
import numpy as np
import pandas as pd
from parsing import PostingHandler, aggregate
from analysis import transformation_pipeline, produce_results
from utils import constants
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/all_data.csv')

# %%
produce_results.job_dist_by_date_plot(df)

# %%
produce_results.posting_dist_by_month_plot(df)

# %%
produce_results.ministry_size_normalize_plot(df)
# Out:
# removing nan ministerio values...

# %%
produce_results.ministry_by_size_plot(df)
# Out:
# removing nan ministerio values...

# %%
produce_results.ministry_num_vac_normalize_plot(df)
# Out:
# removing nan ministerio values...

# %%
produce_results.ministry_num_vac_budget_plot(df)
# Out:
# removing nan ministerio values...

# %%
produce_results.wage_by_month_plot(df)

# %%
produce_results.wage_by_month_all_plot(df)

# %%
produce_results.wage_by_ministry_plot(df)
# Out:
# removing nan ministerio values...

# %%
produce_results.vac_type_dist(df)

# %%
produce_results.wage_by_vac_type_plot(df)

# %%
produce_results.schedule_by_month_plot(df)

# %%
produce_results.days_open_ministry_plot(df)
# Out:
# removing nan ministerio values...

# %%
produce_results.days_open_by_month_all_plot(df)

# %%
produce_results.days_open_contract_type_plot(df)

# %%
produce_results.results_by_contract_type_plot(df)

# %%
produce_results.results_by_ministry_plot(df)
# Out:
# removing nan ministerio values...

# %%
produce_results.results_by_month_plot(df)

# %%
produce_results.results_by_date_plot(df)
